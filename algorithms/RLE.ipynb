# %% [markdown]
# <a href="https://colab.research.google.com/github/thefr33radical/codeblue/blob/master/algorithms/RLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def count_contagious(i,source):
    start_index=i
    end_index=i
    count =1
    while i <len(source)-1:
        if source[i]==source[i+1]:
            count+=1
            i+=1
        else:
            end_index=i
            return count,start_index,end_index
    end_index=i     
    return count,start_index,end_index
    

def encode(source):               
        new_str=""
        i=0
        while i <len(source)-1:
            count=1
            if source[i]==source[i+1]:               
                count,start,end =count_contagious(i,source)
                new_str+=source[start]+str(count)
                i=end
                i+=1
               
            else:               
                new_str+=source[i]+str(count)
                i+=1
               
        count=1        
        if i == len(source)-1:
            count=1
            new_str+=source[i]+str(count)
            i+=1
            
        return new_str

source=input("")
print (encode(source))
# Out:
# front a3 2
# front a3b2 4
# front a3b2c2 6
# front a3b2c2a3 9
# front a3b2c2a3d2 11
# front a3b2c2a3d2e2 13
# front a3b2c2a3d2e2f4 17
# 'a3b2c2a3d2e2f4'

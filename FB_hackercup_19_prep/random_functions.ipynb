# %% [markdown]
# <a href="https://colab.research.google.com/github/thefr33radical/codeblue/blob/master/FB_hackercup_19_prep/random_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Example of service time 
from random import expovariate, gauss
from statistics import mean, median, stdev


average_arrival_interval = 5.6
# initial avg eaiting time
average_service_time = 5.0
#  Initial average service tiem
stdev_service_time = 0.5
# standard deviation of the servixe time

num_waiting = 0
# Initially waiting Q is empty
arrivals = []
# initially arrival q is empty
starts = []

arrival = service_end = 0.0

for i in range(20000):
  # if there are any process running add to arrival Q
    if arrival <= service_end:
        num_waiting += 1
        arrival += expovariate(1.0 / average_arrival_interval)
        arrivals.append(arrival)
    else:
        # if service end open a job from arrival Q
        num_waiting -= 1
        # Decrement wait counter
        service_start = service_end if num_waiting else arrival
        # start time of the job
        service_time = gauss(average_service_time, stdev_service_time)
        # service time of the job
        service_end = service_start + service_time
        # end time of the job
        starts.append(service_start)

waits = [start - arrival for arrival, start in zip(arrivals, starts)]
print(f'Mean wait: {mean(waits):.1f}.  Stdev wait: {stdev(waits):.1f}.')
print(f'Median wait: {median(waits):.1f}.  Max wait: {max(waits):.1f}.')


import random

# print(random.seed(5),random.seed(),random.seed("abc"))
# set random seed as int else take time
print(random.getstate())
# gets the current state of random generator
print(random.randrange(99),random.randrange(12,19,1))
# returns randomly selected integer from random.randrange(start,stop,step)
print(random.choice([1,2,3,4,5,6,7]))
# Select a number from a list
print(random.choices([1,2,3,4,5,6,7],k=2))
# Return a random list of lists with k=2
print(random.shuffle([1,2,3,4,5,6,7]))
# Shuffle a list
print(random.sample([1,2,3,4,5,6,7],k=2))
# Sampling without replacement

## Real valued Distributions

print(random.random())
# Get a random float number
print(random.uniform(2,10))
# Out:
# (3, (2590586201, 2107084936, 3282297508, 96579650, 2704966246, 3221834838, 2591761581, 991072923, 2591325435, 2705329835, 1237899855, 2605542105, 3941388158, 3579855875, 1161951624, 1003252886, 326774410, 3848592010, 3395468611, 3141809395, 2312377333, 1414161458, 92422839, 2323540624, 2933619645, 4281884265, 1913838100, 587582370, 3897832291, 2544525665, 2633935277, 3011999787, 2296377626, 2362351408, 498678554, 2465398341, 3797885606, 1240761902, 2814487279, 812309008, 273089473, 397276252, 380115666, 4206325285, 145921390, 3672923682, 879510597, 3906766467, 1534283848, 1642152357, 3800190886, 3799093648, 1238495773, 338683207, 1279571252, 4047023729, 3335204826, 2870932963, 3417340964, 3511699281, 2246859099, 3257222197, 3856647559, 1405302005, 354712412, 1765590810, 282679257, 1064870864, 1352057303, 2743912356, 3328050398, 1052179577, 1199961172, 2450908975, 2891214985, 694122076, 1425341866, 369388845, 3653087615, 2872258965, 2205542733, 1371867590, 2114065608, 1173478772, 1289869605, 24338459, 267050837, 765618389, 2400004902, 2500043849, 1312681351, 3281432705, 2257826929, 1056626221, 3388671871, 3339916677, 3703309016, 781731660, 4142409550, 2949204508, 4139970520, 2312109583, 349443617, 1711920542, 1916636885, 